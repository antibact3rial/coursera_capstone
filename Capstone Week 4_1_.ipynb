# %% [markdown]
# # Capstone Project
# ## Grocery Store's of the Greater DFW Area
#
# This project will utilize multiple data sources including the US Census, Google Geocoder and Foursquare in order to build out a list of grocery stores in the Greater Dallas-Forth Worth Area. Once we have collected all the data and shaped it into a usuable dataset, we can begin to dig into the question on whether Denton, TX has cross a population threshold that would make a new Grocery Store a profitable investment.

# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
import requests
import json
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
import googlemaps

# %% [markdown]
# Import all the necessary packages to make web requests, read JSON, geocode locations, plot data, cluster the data and draw
# a map.

# %% [markdown]
# Will be querying the US Census to pull down the Population of every city in the following counties:
#
# Dallas County (County Code 113),
#
# Denton County (County Code 121),
#
# Tarrant County (County Code 439)

# %%
df_denton = pd.read_csv("https://api.census.gov/data/2017/pep/population?get=POP,GEONAME&for=place:*&in=state:48%20county:121")
df_denton.rename(columns={'[["POP"':'Population', 'GEONAME':'City', 'place]':'Place'}, inplace=True)
df_denton['Population'] = df_denton['Population'].str[2:-1]
df_denton['City'] = df_denton['City'].str[:-22]
df_denton['Place'] = df_denton['Place'].str[:-1]
df_denton['City'] = df_denton['City'].str.strip('(pt.)')
df_denton['City'] = df_denton['City'].str.replace(' city', "")
df_denton['City'] = df_denton['City'].str.replace(' town', "")
df_denton.drop(columns=['state', 'Unnamed: 5', 'Place'], inplace=True)
df_denton = df_denton[:-1]
df_denton.head()
# Out:
#   Population         City  county
# 0       4100       Argyle     121
# 1       3391       Aubrey     121
# 2       1732  Bartonville     121
# 3      79715  Carrollton      121
# 4          0      Celina      121

# %% [markdown]
# The columns come in quite messy and need to be renamed.
# We will rename the Population, City and Place columns, along with removing redundant information, and random artifacts in the "Pop" and "Place" Columns:

# %%
df_worth = pd.read_csv("https://api.census.gov/data/2017/pep/population?get=POP,GEONAME&for=place:*&in=state:48%20county:439")
df_worth.rename(columns={'[["POP"':'Population', 'GEONAME':'City', 'place]':'Place'}, inplace=True)
df_worth['Population'] = df_worth['Population'].str[2:-1]
df_worth['City'] = df_worth['City'].str[:-22]
df_worth['Place'] = df_worth['Place'].str[:-1]
df_worth['City'] = df_worth['City'].str.strip('(pt.),')
df_worth['City'] = df_worth['City'].str.replace(' city', "")
df_worth['City'] = df_worth['City'].str.replace(' town', "")
df_worth.drop(columns=['state', 'Unnamed: 5', 'Place'], inplace=True)
df_worth = df_worth[:-1]
df_worth.head()
# Out:
#   Population        City  county
# 0     396394   Arlington     439
# 1      10471       Azle      439
# 2      49486     Bedford     439
# 3      23590    Benbrook     439
# 4       2482  Blue Mound     439

# %% [markdown]
# We do the same process for Tarrant County

# %%
df_dal = pd.read_csv("https://api.census.gov/data/2017/pep/population?get=POP,GEONAME&for=place:*&in=state:48%20county:113")
df_dal.rename(columns={'[["POP"':'Population', 'GEONAME':'City', 'place]':'Place'}, inplace=True)
df_dal['Population'] = df_dal['Population'].str[2:-1]
df_dal['City'] = df_dal['City'].str[:-22]
df_dal['Place'] = df_dal['Place'].str[:-1]
df_dal['City'] = df_dal['City'].str.strip('(pt.)')
df_dal['City'] = df_dal['City'].str.replace(' city', "")
df_dal['City'] = df_dal['City'].str.replace(' town', "")
df_dal.drop(columns=['state', 'Unnamed: 5', 'Place'], inplace=True)
df_dal = df_dal[:-1]
df_dal.head()
# Out:
#   Population           City  county
# 0      15458        Addison     113
# 1      25357  Balch Springs     113
# 2      55993    Carrollton      113
# 3      48150    Cedar Hill      113
# 4       4251  Cockrell Hill     113

# %% [markdown]
# And Dallas county.

# %% [markdown]
# Now that the data is cleaned up a bit, its time to add the Longitude and Latitude for each city.

# %%
# The code was removed by Watson Studio for sharing.

# %%
def getCityGeo( city, area ):
    latitude = []
    longitude = []
    cities = city['City'].values

    for c in cities:
        lat_lng_coords = None
        geojson = None
        while(lat_lng_coords is None):
            gmaps = googlemaps.Client(key=API_key)
            #g = geocoder.google(area.format(c))
            lat_lng_coords = gmaps.geocode(area.format(c))
            
    
    
        latitude.append(lat_lng_coords[0]['geometry']['location']['lat'])
        longitude.append(lat_lng_coords[0]['geometry']['location']['lng'])
        #latitude.append(lat_lng_coords[0])
        #longitude.append(lat_lng_coords[1])
    
    city['Latitude'] = latitude
    city['Longitude'] = longitude
    return city

# %% [markdown]
# Run the function for all 3 counties to attach the longitude and latitude to the data set.

# %%
getCityGeo(df_denton,'{}, Denton County, Texas')
getCityGeo(df_worth,'{}, Tarrant County, Texas')
getCityGeo(df_dal,'{}, Dallas County, Texas')
# Out:
#    Population             City  county   Latitude  Longitude
# 0       15458          Addison     113  32.961790 -96.829169
# 1       25357    Balch Springs     113  32.728741 -96.622771
# 2       55993      Carrollton      113  32.975642 -96.889964
# 3       48150      Cedar Hill      113  32.588469 -96.956115
# 4        4251    Cockrell Hill     113  32.736242 -96.886948
# 5         788         Combine      113  32.588468 -96.508599
# 6       41119         Coppell      113  32.954569 -97.015008
# 7     1258325          Dallas      113  32.776664 -96.796988
# 8       53568           DeSoto     113  32.589700 -96.857074
# 9       39487      Duncanville     113  32.651800 -96.908337
# 10      37088   Farmers Branch     113  32.926514 -96.896115
# 11          2          Ferris      113  32.534026 -96.665549
# 12     237647         Garland      113  32.912624 -96.638883
# 13      10071   Glenn Heights      113  32.548748 -96.856667
# 14     133525   Grand Prairie      113  32.745964 -96.997785
# 15          0       Grapevine      113  32.934292 -97.078065
# 16       9208    Highland Park     113  32.833461 -96.791945
# 17       5627         Hutchins     113  32.649300 -96.713052
# 18     240373           Irving     113  32.814018 -96.948894
# 19      39386        Lancaster     113  32.592080 -96.756108
# 20       1256      Lewisville      113  33.046233 -96.994174
# 21     143818        Mesquite      113  32.766796 -96.599159
# 22        377          Ovilla      113  32.526526 -96.886390
# 23      83701      Richardson      113  32.948333 -96.729852
# 24      55286         Rowlett      113  32.902902 -96.563880
# 25      17897          Sachse      113  32.976233 -96.595270
# 26      16690      Seagoville      113  32.639578 -96.538323
# 27       6491        Sunnyvale     113  32.796517 -96.560824
# 28      25201  University Park     113  32.855038 -96.797592
# 29       4136           Wilmer     113  32.589024 -96.685272
# 30        522           Wylie      113  33.015120 -96.538879

# %%
df_dal.head()
# Out:
#   Population           City  county   Latitude  Longitude
# 0      15458        Addison     113  32.961790 -96.829169
# 1      25357  Balch Springs     113  32.728741 -96.622771
# 2      55993    Carrollton      113  32.975642 -96.889964
# 3      48150    Cedar Hill      113  32.588469 -96.956115
# 4       4251  Cockrell Hill     113  32.736242 -96.886948

# %%
df_denton.head()
# Out:
#   Population         City  county   Latitude  Longitude
# 0       4100       Argyle     121  33.121232 -97.183347
# 1       3391       Aubrey     121  33.304283 -96.986118
# 2       1732  Bartonville     121  33.073177 -97.131679
# 3      79715  Carrollton      121  32.975642 -96.889964
# 4          0      Celina      121  33.366454 -96.764097

# %%
df_worth.head()
# Out:
#   Population        City  county   Latitude  Longitude
# 0     396394   Arlington     439  32.735687 -97.108066
# 1      10471       Azle      439  32.895126 -97.545856
# 2      49486     Bedford     439  32.844017 -97.143067
# 3      23590    Benbrook     439  32.673188 -97.460576
# 4       2482  Blue Mound     439  32.856517 -97.338906

# %% [markdown]
# The final step for preparing the initial city dataset is to join together all 3 dataframes into a single data frame.

# %%
df_w = pd.concat([df_denton, df_worth, df_dal], ignore_index=True)
df_w.head()
# Out:
#   Population         City  county   Latitude  Longitude
# 0       4100       Argyle     121  33.121232 -97.183347
# 1       3391       Aubrey     121  33.304283 -96.986118
# 2       1732  Bartonville     121  33.073177 -97.131679
# 3      79715  Carrollton      121  32.975642 -96.889964
# 4          0      Celina      121  33.366454 -96.764097

# %% [markdown]
# # Foursquare Setup

# %%
# The code was removed by Watson Studio for sharing.

# %%
def getNearbyGroceryVenues(names, latitudes, longitudes, pop, categoryId = '4bf58dd8d48988d1f9941735,4bf58dd8d48988d118951735' ):
    grocery_list=[]
    for name, lat, lng, pop in zip(names, latitudes, longitudes, pop):
            
   
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&limit={}&radius={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            lat, 
            lng, 
            API_VERSION,  
            LIMIT,
            radius,
            categoryId)


        results = requests.get(url).json()['response']['venues']
        try:
            x=(results[0]['categories'][0]['id'])
        except:
            x='Nan'
        try:            
            y=(results[0]['categories'][0]['name'])
        except:
            y='Nan'
        try:
            z=(results[0]['location']['postalCode'])
        except:
            z='Nan'
        grocery_list.append([(x, name, lat, lng, v['name'], v['location']['lat'], v['location']['lng'], y, v['location']['distance'], z, pop) for v in results])
            
    dfw_groceryvenues = pd.DataFrame([item for grocery_list in grocery_list for item in grocery_list])
    dfw_groceryvenues.columns = ['Id','City', 'City Latitude', 'City Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category', 'Distance', 'Zip Code', 'Population']
    #dfw_groceryvenues['Population'] = name['Population']
    
    return(dfw_groceryvenues)

# %% [markdown]
# Call the "getNearbyGroceryVenues" function.

# %%
dfw_groceryvenues = getNearbyGroceryVenues(names=df_w['City'], latitudes=df_w['Latitude'], longitudes=df_w['Longitude'], pop=df_w['Population'])

# %%
dfw_groceryvenues.head()
# Out:
#                          Id         City  City Latitude  City Longitude  \
# 0  4bf58dd8d48988d1f9941735       Argyle      33.121232      -97.183347
# 1  4bf58dd8d48988d1f9941735       Argyle      33.121232      -97.183347
# 2  4bf58dd8d48988d118951735       Aubrey      33.304283      -96.986118
# 3  4bf58dd8d48988d118951735       Aubrey      33.304283      -96.986118
# 4  52f2ab2ebcbc57f1066b8b46  Bartonville      33.073177      -97.131679
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0          Hidden Valley Dairy       33.117789       -97.196208
# 1               Boydston Foods       33.151838       -97.164065
# 2          Diamond Supermarket       33.293934       -96.984347
# 3                Diamond Foods       33.293752       -96.984574
# 4  Kroger  Lantana Town Center       33.074904       -97.130014
#
#       Venue Category  Distance Zip Code Population
# 0  Food & Drink Shop      1258    76226       4100
# 1  Food & Drink Shop      3852    76226       4100
# 2      Grocery Store      1163    76227       3391
# 3      Grocery Store      1181    76227       3391
# 4        Supermarket       247      Nan       1732

# %%
dfw_groceryvenues.groupby('City').count().sort_values(by='Zip Code', ascending=False).head()
# Out:
#              Id  City Latitude  City Longitude  Venue  Venue Latitude  \
# City
# Dallas       90             90              90     90              90
# Fort Worth   74             74              74     74              74
# Grapevine    68             68              68     68              68
# Carrollton   60             60              60     60              60
# Addison      50             50              50     50              50
#
#              Venue Longitude  Venue Category  Distance  Zip Code  Population
# City
# Dallas                    90              90        90        90          90
# Fort Worth                74              74        74        74          74
# Grapevine                 68              68        68        68          68
# Carrollton                60              60        60        60          60
# Addison                   50              50        50        50          50

# %%
dfw_groceryvenues.drop('Id', axis=1, inplace=True)

# %% [markdown]
# We create a new dataframe at this point, 'dfw_data' which we will be using the k-means algorithm on.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories=row.iloc[1:]
    row_categories_sorted=row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
dfw_onehot = pd.get_dummies(dfw_groceryvenues[['Venue']], prefix = '', prefix_sep='')
dfw_onehot['City']=dfw_groceryvenues['City']
fixed_columns = [dfw_onehot.columns[-1]]+list(dfw_onehot.columns[:-1])
dfw_onehot= dfw_onehot[fixed_columns]
dfw_onehot.shape
#grouping by neighbourhood
dfw_grouped=dfw_onehot.groupby('City').mean().reset_index()
dfw_grouped
# Out:
#                       City  1 Stop Beer Wine & Cigar  1001 Wine & Spirits  \
# 0                  Addison                       0.0             0.000000
# 1                   Argyle                       0.0             0.000000
# 2                Arlington                       0.0             0.000000
# 3                   Aubrey                       0.0             0.000000
# 4                    Azle                        0.0             0.000000
# 5            Balch Springs                       0.0             0.000000
# 6              Bartonville                       0.0             0.000000
# 7                  Bedford                       0.0             0.000000
# 8                 Benbrook                       0.0             0.000000
# 9               Blue Mound                       0.0             0.000000
# 10               Burleson                        0.0             0.000000
# 11             Carrollton                        0.0             0.000000
# 12             Cedar Hill                        0.0             0.000000
# 13           Cockrell Hill                       0.0             0.000000
# 14             Colleyville                       0.0             0.000000
# 15                Coppell                        0.0             0.000000
# 16           Copper Canyon                       0.0             0.000000
# 17                 Corinth                       0.0             0.000000
# 18             Corral City                       0.0             0.000000
# 19             Cross Roads                       0.0             0.000000
# 20                Crowley                        0.0             0.000000
# 67               0.000000  0.000000          0.0           0.0
# 68               0.000000  0.000000          0.0           0.0
# 69               0.000000  0.000000          0.0           0.0
# 70               0.000000  0.000000          0.0           0.0
# 71               0.000000  0.000000          0.0           0.0
# 72               0.000000  0.000000          0.0           0.0
# 73               0.000000  0.000000          0.0           0.0
# 74               0.000000  0.000000          0.0           0.0
# 75               0.000000  0.000000          0.0           0.0
# 76               0.000000  0.000000          0.0           0.0
# 77               0.000000  0.000000          0.0           0.0
# 78               0.000000  0.000000          0.0           0.0
# 79               0.000000  0.000000          0.0           0.0
# 80               0.000000  0.000000          0.0           0.0
# 81               0.000000  0.000000          0.0           0.0
# 82               0.000000  0.000000          0.0           0.0
# 83               0.000000  0.000000          0.0           0.0
# 84               0.000000  0.000000          0.0           0.0
# 85               0.000000  0.000000          0.0           0.0
# 86               0.000000  0.000000          0.0           0.0
# 87               0.000000  0.000000          0.0           0.0
# 88               0.000000  0.000000          0.0           0.0
# 89               0.000000  0.000000          0.0           0.0
# 90               0.000000  0.000000          0.0           0.0
# 91               0.000000  0.000000          0.0           0.0
# 92               0.000000  0.000000          0.0           0.0
# 93               0.000000  0.000000          0.0           0.0
# 94               0.000000  0.000000          0.0           0.0
# 95               0.000000  0.000000          0.0           0.0
# 96               0.000000  0.000000          0.0           0.0
#
# [97 rows x 733 columns]

# %%
#sorting in descending order
num_top_venues=5
indicators=['st','nd','rd']
columns=['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append("{}{} Most Common Venue".format(ind+1,indicators[ind]))
    except:
        columns.append("{}th Most Common Venue".format(ind+1))
#new dataframe
dfw_venuessorted = pd.DataFrame(columns=columns)
dfw_venuessorted['City']=dfw_grouped['City']
for ind in np.arange(dfw_grouped.shape[0]):
    dfw_venuessorted.iloc[ind,1:] = return_most_common_venues(dfw_grouped.iloc[ind, :], num_top_venues)
dfw_venuessorted.head()
# Out:
#         City 1st Most Common Venue 2nd Most Common Venue  \
# 0    Addison             Tom Thumb                   GNC
# 1     Argyle        Boydston Foods   Hidden Valley Dairy
# 2  Arlington         Family Dollar              QuikTrip
# 3     Aubrey         Diamond Foods   Diamond Supermarket
# 4      Azle            Apex Liquor   Walmart Supercenter
#
#    3rd Most Common Venue            4th Most Common Venue  \
# 0  Culinary Art Catering  Stuart's Exquisite Services LLC
# 1           whistle stop                       Friendly's
# 2                 Kroger                              GNC
# 3        Freshomatic USA      Garden Ridge Farmers Market
# 4        Majestic Liquor    Majestic Spirits, Beer & Wine
#
#           5th Most Common Venue
# 0                   Barrel King
# 1           General Parts Group
# 2  Dana Bazaar Indian Groceries
# 3        GNC - Valley View Mall
# 4               Farmer's Market

# %% [markdown]
# We create a new dataframe at this point, 'dfw_data' which we will be using the k-means algorithm on.

# %%
dfw_data = df_w
store_density = pd.DataFrame(dfw_groceryvenues['City'].value_counts().reset_index().rename(columns={'index': 'city', 'City': 'count'}))
store_density = store_density.sort_values(by='city', ascending=True)
store_density['Zip Code'] = dfw_groceryvenues['Zip Code']
dfw_data = dfw_data.join(store_density.set_index('city'), on='City')
dfw_data = dfw_data[['Population', 'City', 'Latitude', 'Longitude', 'count', 'county', 'Zip Code']]
dfw_data = dfw_data.rename(columns={'count' : 'Store Count'})
dfw_data = dfw_data.dropna()
dfw_data['Population'] = pd.to_numeric(dfw_data['Population'], errors='coerce')
dfw_data['Zip Code'] = pd.to_numeric(dfw_data['Zip Code'], errors='coerce')
dfw_data['Popdense'] = dfw_data['Population']/dfw_data['Store Count']
dfw_data = dfw_data.dropna()
dfw_data.head()
# Out:
#    Population         City   Latitude  Longitude  Store Count  county  \
# 0        4100       Argyle  33.121232 -97.183347          2.0     121
# 1        3391       Aubrey  33.304283 -96.986118          2.0     121
# 2        1732  Bartonville  33.073177 -97.131679          5.0     121
# 3       79715  Carrollton   32.975642 -96.889964         60.0     121
# 5         822     Coppell   32.954569 -97.015008         20.0     121
#
#    Zip Code     Popdense
# 0   76205.0  2050.000000
# 1   76205.0  1695.500000
# 2   76205.0   346.400000
# 3   76227.0  1328.583333
# 5   75019.0    41.100000

# %% [markdown]
# # K-Means Clustering

# %%
# set number of clusters
kclusters = 10

dfw_grouped_clustering = dfw_data.drop('City', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dfw_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([6, 6, 6, 4, 6, 6, 6, 6, 9, 8], dtype=int32)

# %%
dfw_merged = dfw_data

# add clustering labels
dfw_merged['Cluster Labels'] = kmeans.labels_

dfw_merged = dfw_merged.join(dfw_venuessorted.set_index('City'), on='City')
dfw_merged.head()
# Out:
#    Population         City   Latitude  Longitude  Store Count  county  \
# 0        4100       Argyle  33.121232 -97.183347          2.0     121
# 1        3391       Aubrey  33.304283 -96.986118          2.0     121
# 2        1732  Bartonville  33.073177 -97.131679          5.0     121
# 3       79715  Carrollton   32.975642 -96.889964         60.0     121
# 5         822     Coppell   32.954569 -97.015008         20.0     121
#
#    Zip Code     Popdense  Cluster Labels 1st Most Common Venue  \
# 0   76205.0  2050.000000               6        Boydston Foods
# 1   76205.0  1695.500000               6         Diamond Foods
# 2   76205.0   346.400000               6    Kroger Marketplace
# 3   76227.0  1328.583333               4   Walmart Supercenter
# 5   75019.0    41.100000               6             Tom Thumb
#
#     2nd Most Common Venue          3rd Most Common Venue  \
# 0     Hidden Valley Dairy                   whistle stop
# 1     Diamond Supermarket                Freshomatic USA
# 2  Bartonville Food Store  Lone Star Country Corner Stop
# 3   Walmart Garden Center            Kelly's Beer & Wine
# 5  Coppell Farmers Market                            GNC
#
#          4th Most Common Venue        5th Most Common Venue
# 0                   Friendly's          General Parts Group
# 1  Garden Ridge Farmers Market       GNC - Valley View Mall
# 2             Stir-ups Liquors  Kroger  Lantana Town Center
# 3                     Tatering                          GNC
# 5            Bountiful baskets                     QuikTrip

# %%
add_dfw = 'DFW'

geolocator_dfw = Nominatim()
location_dfw = geolocator_dfw.geocode(add_dfw)
latitude_dfw = location_dfw.latitude
longitude_dfw = location_dfw.longitude
print('The geograpical coordinate of DFW Area are {}, {}.'.format(latitude_dfw, longitude_dfw))
# Out:
# The geograpical coordinate of DFW Area are 32.89651945, -97.0465220537124.

# %% [markdown]
# ## Mapping the K-Means Output

# %%
# visulaize clusters
map_clusters=folium.Map(location=[latitude_dfw,longitude_dfw],zoom_start=12)
x = np.arange(kclusters)
ys=[i+x+(i*x)**2 for i in range(kclusters)]
colors_array=cm.rainbow(np.linspace(0,1,len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
#add markers
markers_colors=[]
for lat, lon, poi, cluster in zip(dfw_merged['Latitude'],dfw_merged['Longitude'], dfw_merged['City'], dfw_merged['Cluster Labels']):
    label=folium.Popup(str(poi)+' Cluster '+str(cluster),parse_html=True)
    folium.CircleMarker(
        [lat,lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Reviewing the individual Cluster Types

# %% [markdown]
# Cluster 0 seems to be focused on the places with the least population or fewest stores.

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 0, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#                  City  county  Zip Code     Popdense  Cluster Labels  \
# 22   Highland Village     121   75077.0   975.705882               0
# 43       Trophy Club      121   75019.0   538.545455               0
# 48           Benbrook     439   76205.0  3931.666667               0
# 51        Colleyville     439   75006.0  1212.454545               0
# 52           Crowley      439   75077.0  1279.500000               0
# 58        Forest Hill     439   75077.0   761.941176               0
# 78            Saginaw     439   75006.0   821.928571               0
# 82            Watauga     439   75006.0   745.515152               0
# 86   White Settlement     439   75006.0   614.758621               0
# 88      Balch Springs     113   75006.0  1056.541667               0
# 112           Sachse      113   76210.0  1789.700000               0
# 113       Seagoville      113   76205.0  4172.500000               0
#
#       1st Most Common Venue         2nd Most Common Venue  \
# 22       Goody Goody Liquor           Walmart Supercenter
# 43   Walmart Grocery Pickup              Sun Fresh Market
# 48   Walmart Grocery Pickup                 Family Dollar
# 51                Tom Thumb        Walmart Grocery Pickup
# 52   Walmart Grocery Pickup          front end of krogers
# 58            Family Dollar                      QuikTrip
# 78                   Kroger                      QuikTrip
# 82                 QuikTrip                 Family Dollar
# 86                 QuikTrip                    Albertsons
# 88            Family Dollar   Walmart Neighborhood Market
# 112                     GNC                        Kroger
# 113     Walmart Supercenter  White's Deli & Country Store
#
#              3rd Most Common Venue 4th Most Common Venue  \
# 22   Majestic Spirits, Beer & Wine   Edible Arrangements
# 43               Roanoke Nutrition          Mumbai Place
# 48                   Hugo's Liquor              QuikTrip
# 51        Tivoli Wines and Spirits   Mirage Fine Spirits
# 52             Walmart Supercenter         Family Dollar
# 58                Bibere Beverages              Foodland
# 78     Kroger Marketplace- Saginaw     Big Daddys Liquor
# 82                      Albertsons                   GNC
# 86             Walmart Supercenter         Family Dollar
# 88                    Liquor Depot         Mom's Grocery
# 112                  Beverage Zone   Walmart Supercenter
# 113                   Brookshire's         Family Dollar
#
#                5th Most Common Venue
# 22                         Tom Thumb
# 43     Majestic Spirits, Beer & Wine
# 48               Walmart Supercenter
# 51       Walmart Neighborhood Market
# 52                  Empire Nutrition
# 58               Prime Valley Liquor
# 78   Big Daddy's Fine Wine & Spirits
# 82           Watauga Farmer's Market
# 86            Walmart Grocery Pickup
# 88                          QuikTrip
# 112                  Jacob’s Liquors
# 113                              GNC

# %% [markdown]
# Cluster 1 has a much higher population density.

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 1, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#            City  county  Zip Code      Popdense  Cluster Labels  \
# 59  Fort Worth      439   76226.0  11687.513514               1
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 59         Family Dollar      Simply Fit Meals              QuikTrip
#
#    4th Most Common Venue 5th Most Common Venue
# 59      Burgundy's Local       Natural Grocers

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 2, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#          City  county  Zip Code     Popdense  Cluster Labels  \
# 99   Garland      113   75006.0  7201.424242               2
# 105    Irving     113   75006.0  8288.724138               2
#
#     1st Most Common Venue        2nd Most Common Venue 3rd Most Common Venue  \
# 99          Family Dollar  Walmart Neighborhood Market              QuikTrip
# 105         Family Dollar                  Fiesta Mart              QuikTrip
#
#     4th Most Common Venue 5th Most Common Venue
# 99       Walmart Pharmacy    Ohana Hawaiian BBQ
# 105                Kroger                  ALDI

# %% [markdown]
# Cluster 3 is for Dallas, which stands out as the most population and the most stores.

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 3, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#        City  county  Zip Code      Popdense  Cluster Labels  \
# 94  Dallas      113   76226.0  13981.388889               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 94         Family Dollar                  ALDI                Kroger
#
#    4th Most Common Venue  5th Most Common Venue
# 94           In the Sack  Market Provisions Co.

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 4]#, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#     Population                  City   Latitude  Longitude  Store Count  \
# 3        79715           Carrollton   32.975642 -96.889964         60.0
# 14       76414         Flower Mound   33.014567 -97.096955         24.0
# 16       68052               Frisco   33.150674 -96.823612         25.0
# 69       66755            Mansfield   32.563192 -97.141677         12.0
# 71       70441  North Richland Hills  32.834295 -97.228903         34.0
#
#     county  Zip Code     Popdense  Cluster Labels 1st Most Common Venue  \
# 3      121   76227.0  1328.583333               4   Walmart Supercenter
# 14     121   75006.0  3183.916667               4             Tom Thumb
# 16     121   75006.0  2722.080000               4                Kroger
# 69     439   75077.0  5562.916667               4              QuikTrip
# 71     439   75006.0  2071.794118               4              QuikTrip
#
#      2nd Most Common Venue      3rd Most Common Venue  \
# 3    Walmart Garden Center        Kelly's Beer & Wine
# 14  Michael Owens Catering     Sprouts Farmers Market
# 16                QuikTrip                        GNC
# 69               Tom Thumb  Dr Kimberli Omwanghe M.D.
# 71           Family Dollar                        GNC
#
#           4th Most Common Venue  5th Most Common Venue
# 3                      Tatering                    GNC
# 14  Walmart Neighborhood Market                Tarkari
# 16                Market Street  Vitality Bowls Frisco
# 69       Walmart Grocery Pickup             WineStyles
# 71  Walmart Neighborhood Market                 Kroger

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 5]#, dfw_merged.columns[[0] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#     Population       City   Latitude  Longitude  Store Count  county  \
# 45      396394  Arlington  32.735687 -97.108066         44.0     439
#
#     Zip Code     Popdense  Cluster Labels 1st Most Common Venue  \
# 45   75006.0  9008.954545               5         Family Dollar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 45              QuikTrip                Kroger                   GNC
#
#            5th Most Common Venue
# 45  Dana Bazaar Indian Groceries

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 6]#, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#      Population                    City   Latitude  Longitude  Store Count  \
# 0          4100                  Argyle  33.121232 -97.183347          2.0
# 1          3391                  Aubrey  33.304283 -96.986118          2.0
# 2          1732             Bartonville  33.073177 -97.131679          5.0
# 5           822                Coppell   32.954569 -97.015008         20.0
# 6          1457           Copper Canyon  33.095955 -97.096678          9.0
# 8            45             Corral City  33.100122 -97.226127          3.0
# 9          1302             Cross Roads  33.231828 -97.002291          5.0
# 13         3079              Double Oak  33.065122 -97.110567         12.0
# 15         9284             Fort Worth   32.755488 -97.330766         74.0
# 17            0              Grapevine   33.003765 -96.870178         68.0
# 18         1099               Hackberry  33.152342 -96.917782         12.0
# 19            0                 Haslet   32.974847 -97.347796          2.0
# 20          417                 Hebron   33.028608 -96.898436         17.0
# 21         4596           Hickory Creek  33.122343 -97.043065         11.0
# 23         3847                  Justin  33.084844 -97.296129          4.0
# 24         1695             Krugerville  33.281506 -96.990563          3.0
# 25         5020                    Krum  33.261507 -97.238073          1.0
# 26         7958             Lake Dallas  33.119287 -97.025564         11.0
# 27          872        Lakewood Village  33.142620 -96.969451          1.0
# 29          521            Lincoln Park  33.222063 -96.972784          4.0
# 33         4339            Pilot Point   33.396503 -96.960561          5.0
# 34         6019                  Plano   33.050717 -96.859226         35.0
# 36          893                Prosper   33.236228 -96.801110          8.0
# 37         7127      Providence Village  33.233386 -96.962438          6.0
# 38         8135                Roanoke   33.004013 -97.225848         22.0
# 39         8255                  Sanger  33.363171 -97.173903          5.0
# 41          922              Southlake   32.941236 -97.134178         40.0
# 44           22               Westlake   32.991235 -97.195014         24.0
# 46        10471                   Azle   32.895126 -97.545856          8.0
# 49         2482              Blue Mound  32.856517 -97.338906         22.0
# 50         9802               Burleson   32.542082 -97.320849         18.0
# 53         2387  Dalworthington Gardens  32.702910 -97.155289         40.0
# 54         3021       Edgecliff Village  32.657634 -97.342794         28.0
# 56         6348                 Everman  32.630968 -97.289182         14.0
# 57          267           Flower Mound   33.014567 -97.096955         24.0
# 63         1844                 Haslet   32.974847 -97.347796          2.0
# 66         8338               Kennedale  32.646801 -97.225847         10.0
# 67         1391                Lakeside  32.822350 -97.493355          1.0
# 68         4960              Lake Worth  32.804851 -97.445020         15.0
# 70            0                 Newark   33.001236 -97.484466          1.0
# 72         2543                 Pantego  32.714299 -97.156400         29.0
# 73         1750             Pelican Bay  32.920959 -97.518356          7.0
# 74            5                   Reno   32.944292 -97.577246          1.0
# 75         8052          Richland Hills  32.815962 -97.228069         29.0
# 76         7703              River Oaks  32.777074 -97.394463         24.0
# 77            0                Roanoke   32.975062 -97.228916         22.0
# 79         5836             Sansom Park  32.805962 -97.403074         25.0
# 81          492            Trophy Club   32.997901 -97.183625         22.0
# 83         1461               Westlake   32.991235 -97.195014         24.0
# 84          694          Westover Hills  32.744852 -97.413630         40.0
# 85         2726       Westworth Village  32.760480 -97.424616         29.0
# 91         4251           Cockrell Hill  32.736242 -96.886948         36.0
# 98            2                 Ferris   32.534026 -96.665549          2.0
# 102           0              Grapevine   32.934292 -97.078065         68.0
# 104        5627                Hutchins  32.649300 -96.713052          3.0
# 114        6491               Sunnyvale  32.796517 -96.560824          1.0
# 116        4136                  Wilmer  32.589024 -96.685272          2.0
# 117         522                  Wylie   33.015120 -96.538879         10.0
#
#      county  Zip Code     Popdense  Cluster Labels  \
# 0       121   76205.0  2050.000000               6
# 1       121   76205.0  1695.500000               6
# 2       121   76205.0   346.400000               6
# 5       121   75019.0    41.100000               6
# 6       121   76226.0   161.888889               6
# 8       121   76205.0    15.000000               6
# 9       121   76205.0   260.400000               6
# 13      121   75077.0   256.583333               6
# 15      121   76226.0   125.459459               6
# 17      121   76227.0     0.000000               6
# 18      121   76210.0    91.583333               6
# 19      121   76205.0     0.000000               6
# 20      121   75019.0    24.529412               6
# 21      121   76210.0   417.818182               6
# 23      121   76205.0   961.750000               6
# 24      121   76205.0   565.000000               6
# 25      121   76205.0  5020.000000               6
# 26      121   76210.0   723.454545               6
# 27      121   76205.0   872.000000               6
# 29      121   76205.0   130.250000               6
# 33      121   76205.0   867.800000               6
# 34      121   75006.0   171.971429               6
# 36      121   76226.0   111.625000               6
# 37      121   76205.0  1187.833333               6
# 38      121   75006.0   369.772727               6
# 39      121   76205.0  1651.000000               6
# 41      121   75006.0    23.050000               6
# 44      121   75006.0     0.916667               6
# 46      439   76226.0  1308.875000               6
# 49      439   75019.0   112.818182               6
# 50      439   75019.0   544.555556               6
# 53      439   75006.0    59.675000               6
# 54      439   75006.0   107.892857               6
# 56      439   75077.0   453.428571               6
# 57      439   75006.0    11.125000               6
# 63      439   76205.0   922.000000               6
# 66      439   76210.0   833.800000               6
# 67      439   76205.0  1391.000000               6
# 68      439   75077.0   330.666667               6
# 70      439   76205.0     0.000000               6
# 72      439   75006.0    87.689655               6
# 73      439   76205.0   250.000000               6
# 74      439   76205.0     5.000000               6
# 75      439   75006.0   277.655172               6
# 76      439   75006.0   320.958333               6
# 77      439   75006.0     0.000000               6
# 79      439   75006.0   233.440000               6
# 81      439   75019.0    22.363636               6
# 83      439   75006.0    60.875000               6
# 84      439   75006.0    17.350000               6
# 85      439   75006.0    94.000000               6
# 91      113   75006.0   118.083333               6
# 98      113   76205.0     1.000000               6
# 102     113   76227.0     0.000000               6
# 104     113   76205.0  1875.666667               6
# 114     113   76205.0  6491.000000               6
# 116     113   76205.0  2068.000000               6
# 117     113   76210.0    52.200000               6
#
#               1st Most Common Venue            2nd Most Common Venue  \
# 0                    Boydston Foods              Hidden Valley Dairy
# 1                     Diamond Foods              Diamond Supermarket
# 2                Kroger Marketplace           Bartonville Food Store
# 5                         Tom Thumb           Coppell Farmers Market
# 6            Walmart Grocery Pickup                   Vitamin Shoppe
# 8               Hidden Valley Dairy                 Paradise Liquors
# 9               Walmart Supercenter           Walmart Grocery Pickup
# 13                              GNC      Sub Zero Nitrogen Ice Cream
# 15                    Family Dollar                 Simply Fit Meals
# 17                         QuikTrip                              GNC
# 18             Walmart Photo Center           AJ Spirit Wine & Gifts
# 19            Haslet Farmers Market    Geordanes Neighborhood Market
# 20                 R&J Asian Spices       Castle Hills Village Plaza
# 21                              GNC      Tri-Cities Liquor-Beer-Wine
# 23                  Flamingo Liquor                     krispy kreme
# 24                    Diamond Foods              Diamond Supermarket
# 25   Extreme Cuisine Catering, Krum                     whistle stop
# 26      Garden Ridge Farmers Market              Fossil Creek Liquor
# 27                     Elm's Liquor                     whistle stop
# 29              Walmart Supercenter                              GNC
# 33     Brookshire Brothers Pharmacy          Stephen's Grocery Store
# 34                           Spec's  Centennial Spirits, Beer & Wine
# 36              Walmart Supercenter           Walmart Grocery Pickup
# 37              Walmart Supercenter                              GNC
# 38                         QuikTrip                        Tom Thumb
# 39                       Super Save                    Family Dollar
# 41                        Tom Thumb                              GNC
# 44                           Cheers  Fossil Creek Liquor - West Lake
# 46                      Apex Liquor              Walmart Supercenter
# 49                         QuikTrip                           Kroger
# 50      Walmart Neighborhood Market              Walmart Supercenter
# 53                         QuikTrip                           Kroger
# 54                    Family Dollar                         QuikTrip
# 56                         QuikTrip                    Family Dollar
# 57                        Tom Thumb           Michael Owens Catering
# 63            Haslet Farmers Market    Geordanes Neighborhood Market
# 66           Walmart Grocery Pickup                         QuikTrip
# 67   Ridgmar Farmers Market Inc. II                     whistle stop
# 68                     Brookshire's                  Longhorn Liquor
# 70                    Family Dollar                  Freshomatic USA
# 72                           Kroger                           Spec's
# 73              Walmart Supercenter                       Albertsons
# 74                 Always Supersave                     whistle stop
# 75                         QuikTrip                           Kroger
# 76                    Family Dollar                         QuikTrip
# 77                         QuikTrip                        Tom Thumb
# 79                         QuikTrip                    Family Dollar
# 81           Walmart Grocery Pickup                 Sun Fresh Market
# 83                           Cheers  Fossil Creek Liquor - West Lake
# 84                              GNC                         QuikTrip
# 85                              GNC                    Family Dollar
# 91                    Family Dollar                             ALDI
# 98              Brookshire Brothers                    Family Dollar
# 102                        QuikTrip                              GNC
# 104                   Family Dollar                         QuikTrip
# 114             Walmart Supercenter                  Freshomatic USA
# 116                   Family Dollar                    Legacy Liquor
# 117              Kroger Marketplace         1 Stop Beer Wine & Cigar
#
#                     3rd Most Common Venue          4th Most Common Venue  \
# 0                            whistle stop                     Friendly's
# 1                         Freshomatic USA    Garden Ridge Farmers Market
# 2           Lone Star Country Corner Stop               Stir-ups Liquors
# 5                                     GNC              Bountiful baskets
# 6                                     GNC             Whole Foods Market
# 8           Paradise Spirits & Fine Wines                   whistle stop
# 9                         Jacob's Liquors          Walmart Garden Center
# 13                           World Market    Kroger  Lantana Town Center
# 15                               QuikTrip               Burgundy's Local
# 17                    Walmart Supercenter                      Tom Thumb
# 38           Cheers Wine and Spirits
# 39               Hunter's Choice LLC
# 41                        WineStyles
# 44                         Tom Thumb
# 46                   Farmer's Market
# 49   Big Daddy's Fine Wine & Spirits
# 50                            Kroger
# 53       Walmart Neighborhood Market
# 54                        Xo Liquors
# 56                  Bibere Beverages
# 57                           Tarkari
# 63                               GNC
# 66                       Apple Jacks
# 67                               GNC
# 68               Walmart Supercenter
# 70                               GNC
# 72                Farm to Fork Foods
# 73                       Apex Liquor
# 74       Garden Ridge Farmers Market
# 75                     Family Dollar
# 76               Walmart Supercenter
# 77           Cheers Wine and Spirits
# 79                        Albertsons
# 81     Majestic Spirits, Beer & Wine
# 83                         Tom Thumb
# 84            Ridgmar Farmers Market
# 85                              Aldi
# 91         Amigos Liquor Beer & Wine
# 98            GNC - Valley View Mall
# 102         The Spice & Tea Exchange
# 104              Fossil Creek Liquor
# 114                              GNC
# 116           GNC - Valley View Mall
# 117               Kroger Cheese Shop

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 7]#, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#      Population            City   Latitude  Longitude  Store Count  county  \
# 47        49486         Bedford  32.844017 -97.143067         20.0     439
# 55        55174          Euless  32.837073 -97.081954         27.0     439
# 60        60284  Grand Prairie   32.745964 -96.997785         34.0     439
# 61        53982      Grapevine   32.934292 -97.078065         68.0     439
# 65        47266          Keller  32.934189 -97.229298         10.0     439
# 89        55993     Carrollton   32.975642 -96.889964         60.0     113
# 90        48150     Cedar Hill   32.588469 -96.956115         13.0     113
# 95        53568          DeSoto  32.589700 -96.857074         18.0     113
# 111       55286        Rowlett   32.902902 -96.563880         13.0     113
#
#      Zip Code     Popdense  Cluster Labels 1st Most Common Venue  \
# 47    75019.0  2474.300000               7                Kroger
# 55    75006.0  2043.481481               7              QuikTrip
# 60    75006.0  1773.058824               7         Family Dollar
# 61    76227.0   793.852941               7              QuikTrip
# 65    76210.0  4726.600000               7                   GNC
# 89    76227.0   933.216667               7   Walmart Supercenter
# 90    75077.0  3703.846154               7         Family Dollar
# 95    75019.0  2976.000000               7                  ALDI
# 111   75077.0  4252.769231               7              QuikTrip
#
#       2nd Most Common Venue       3rd Most Common Venue  \
# 47            Family Dollar                    QuikTrip
# 55            Family Dollar         Scratch Cafe & Shop
# 60                 QuikTrip  El Rio Grande Latin Market
# 61                      GNC         Walmart Supercenter
# 65            Super Suppers             Natural Grocers
# 89    Walmart Garden Center         Kelly's Beer & Wine
# 90   Walmart Grocery Pickup                        ALDI
# 95      Walmart Supercenter               Family Dollar
# 111   Walmart Garden Center                 Goody Goody
#
#            4th Most Common Venue          5th Most Common Venue
# 47                           GNC                       Foodland
# 55            Bombay Grocery & +                     Albertsons
# 60               Terry's Mercado                         Kroger
# 61                     Tom Thumb       The Spice & Tea Exchange
# 65                      QuikTrip                      Tom Thumb
# 89                      Tatering                            GNC
# 90                           GNC         Tastee Plates Catering
# 95   Walmart Neighborhood Market  The Daiquiri Factory and Cafe
# 111       Sprouts Farmers Market         Walmart Grocery Pickup

# %% [markdown]
# ## Denton
#
# The goal was to see whether Denton needs a new store at this time. It seems these numbers suggest that it is a prime location to build a new store based on the optimal ratio of Population and Store availability.

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 8]#, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#      Population            City   Latitude  Longitude  Store Count  county  \
# 11       136268          Denton  33.214841 -97.133068         45.0     121
# 101      133525  Grand Prairie   32.745964 -96.997785         34.0     113
# 108      143818       Mesquite   32.766796 -96.599159         21.0     113
#
#      Zip Code     Popdense  Cluster Labels 1st Most Common Venue  \
# 11    75006.0  3028.177778               8                Kroger
# 101   75006.0  3927.205882               8         Family Dollar
# 108   75019.0  6848.476190               8         Family Dollar
#
#     2nd Most Common Venue       3rd Most Common Venue 4th Most Common Venue  \
# 11              La Azteca    Austin Street Truck Stop         Market On Oak
# 101              QuikTrip  El Rio Grande Latin Market       Terry's Mercado
# 108              QuikTrip                  Albertsons    LAREDO MEAT MARKET
#
#     5th Most Common Venue
# 11          Ken's Produce
# 101                Kroger
# 108             Taj Mahal

# %%
dfw_merged.loc[dfw_merged['Cluster Labels'] == 9]#, dfw_merged.columns[[1] + list(range(5, dfw_merged.shape[1]))]]
# Out:
#     Population            City   Latitude  Longitude  Store Count  county  \
# 10       30503         Dallas   33.199165 -97.123983         90.0     121
# 42       42721      The Colony  33.080608 -96.892831         20.0     121
# 62       44417     Haltom City  32.799574 -97.269182         28.0     439
# 64       39051           Hurst  32.823462 -97.170568         22.0     439
# 80       30902      Southlake   32.941236 -97.134178         40.0     439
# 93       41119        Coppell   32.954569 -97.015008         20.0     113
# 96       39487     Duncanville  32.651800 -96.908337         31.0     113
# 97       37088  Farmers Branch  32.926514 -96.896115         22.0     113
#
#     Zip Code     Popdense  Cluster Labels   1st Most Common Venue  \
# 10   76226.0   338.922222               9           Family Dollar
# 42   75019.0  2136.050000               9     The Thirsty Growler
# 62   75006.0  1586.321429               9           Family Dollar
# 64   75006.0  1775.045455               9  Walmart Grocery Pickup
# 80   75006.0   772.550000               9               Tom Thumb
# 93   75019.0  2055.950000               9               Tom Thumb
# 96   75006.0  1273.774194               9           Family Dollar
# 97   75019.0  1685.818182               9                QuikTrip
#
#           2nd Most Common Venue  3rd Most Common Venue  \
# 10                         ALDI                 Kroger
# 42           Kroger Marketplace                 Spec's
# 62  Walmart Neighborhood Market               QuikTrip
# 64                     QuikTrip                    GNC
# 80                          GNC           Fresh Market
# 93       Coppell Farmers Market                    GNC
# 96                     QuikTrip    Walmart Supercenter
# 97  Walmart Neighborhood Market  La Azteca Meat Market
#
#           4th Most Common Venue        5th Most Common Venue
# 10                  In the Sack        Market Provisions Co.
# 42                    Water Inn          Walmart Supercenter
# 62   Fort Worth Discount Liquor         Trav's  Liqour Store
# 64  Walmart Neighborhood Market                       Kroger
# 80              Fresh Fit Foods                   WineStyles
# 93            Bountiful baskets                     QuikTrip
# 96                         ALDI            Red Bird Dialysis
# 97          Ko'mart Marketplace  KETTLE-COOKED CRAFTERS, LLC
